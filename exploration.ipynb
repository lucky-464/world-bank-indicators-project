# %%
import pandas as pd
import numpy as np

# %%
df_WB = pd.read_excel("/Users/abhishek/Desktop/World_bank_indicators _analytics/WDIEXCEL.xlsx")

# %%
df_WB.head()
# Out:
#                   Country Name Country Code  \
# 0  Africa Eastern and Southern          AFE
# 1  Africa Eastern and Southern          AFE
# 2  Africa Eastern and Southern          AFE
# 3  Africa Eastern and Southern          AFE
# 4  Africa Eastern and Southern          AFE
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 1  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS   NaN
# 2  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2016       2017       2018  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  18.685118  19.205632  19.742772
# 1   NaN   NaN   NaN   NaN   NaN  ...   7.606712   7.926604   8.309896
# ...

# %%
df_WB.shape
# Out:
# (396970, 70)

# %%
df_WB.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024', '2025'],
#       dtype='object')

# %%
WB_copy = df_WB

# %%
WB_copy.head()
# Out:
#                   Country Name Country Code  \
# 0  Africa Eastern and Southern          AFE
# 1  Africa Eastern and Southern          AFE
# 2  Africa Eastern and Southern          AFE
# 3  Africa Eastern and Southern          AFE
# 4  Africa Eastern and Southern          AFE
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 1  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS   NaN
# 2  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2016       2017       2018  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  18.685118  19.205632  19.742772
# 1   NaN   NaN   NaN   NaN   NaN  ...   7.606712   7.926604   8.309896
# ...

# %%
df_new = WB_copy.dropna() # drop the rows with atleast one element missing

# %%
df_WB.isna().sum()#Indicate missing values.
# Out:
# Country Name           0
# Country Code           0
# Indicator Name         0
# Indicator Code         0
# 1960              359744
#                    ...
# 2021              185497
# 2022              198974
# 2023              212798
# 2024              246812
# 2025              315299
# Length: 70, dtype: int64

# %%
  WB_copy.isnull().sum()
# Out:
# Country Name           0
# Country Code           0
# Indicator Name         0
# Indicator Code         0
# 1960              359744
#                    ...
# 2021              185497
# 2022              198974
# 2023              212798
# 2024              246812
# 2025              315299
# Length: 70, dtype: int64

# %%
len(df_new)
# Out:
# 24314

# %%
len(WB_copy)
# Out:
# 396970

# %%
# Task 1: Find out how many distinct sheets exist in the Excel workbook and inspect their labels.
WB_excel = pd.ExcelFile("/Users/abhishek/Desktop/World_bank_indicators _analytics/WDIEXCEL.xlsx")
sheet_names = WB_excel.sheet_names
print(sheet_names)
# Task 2: Load the specific metadata sheet that contains indicator definitions and topics into a DataFrame.
df_indicator = pd.read_excel(WB_excel, sheet_name ='Series')
print(df_indicator.head())
# Task 3: Group or count the indicators by their broad development topic to see the distribution.
#Group by in the pandass yehhh--> okay broo 
df_indicator.groupby('Topic')['Indicator Name'].count()
# Out:
# ['Data', 'Country', 'Series', 'country-series', 'series-time', 'footnote']
#          Series Code                                 Topic  \
# 0  AG.CON.FERT.PT.ZS  Environment: Agricultural production
# 1     AG.CON.FERT.ZS  Environment: Agricultural production
# 2     AG.LND.AGRI.K2                 Environment: Land use
# 3     AG.LND.AGRI.ZS                 Environment: Land use
# 4     AG.LND.ARBL.HA                 Environment: Land use
#
#                                       Indicator Name  Short definition  \
# 0  Fertilizer consumption (% of fertilizer produc...               NaN
# 1  Fertilizer consumption (kilograms per hectare ...               NaN
# 2                         Agricultural land (sq. km)               NaN
# 3                 Agricultural land (% of land area)               NaN
# 4                             Arable land (hectares)               NaN
#
#                                      Long definition  \
# ...
