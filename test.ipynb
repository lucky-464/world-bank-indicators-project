# %%
pip install duckdb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 3.2 MB/s  0:00:04m 3.2 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import duckdb
duckdb.sql("SELECT 42 AS answer").show()
# Out:
# ┌────────┐
# │ answer │
# │ int32  │
# ├────────┤
# │     42 │
# └────────┘
